# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %% [markdown]
# ### Import Crime Data
# Was downloaded to /data directory as 'chicago30dayData22sep2020.csv' from
#
# Excel CSV file from [Chicago Data Portal](https://data.cityofchicago.org/Public-Safety/Crimes-Last-30-days/fjjk-7e4n)

# %%
# Excel CSV file from [Chicago Data Portar](https://data.cityofchicago.org/Public-Safety/Crimes-Last-30-days/fjjk-7e4n)
raw_file = '../data/raw/chicago30dayData22sep2020.csv'

# %%
crime_data = pd.read_csv(raw_file)

# %%
crime_data
# Out:
#              ID Case Number                    Date                   Block  \
# 0      11029532    JA361567  12/01/2013 09:00:00 PM    021XX N MULLIGAN AVE
# 1      11038135    JA372338  11/16/2013 12:00:00 AM        007XX E 103RD PL
# 2      11237754    JB161591  10/03/2013 09:00:00 AM     009XX N HARDING AVE
# 3      11241055    JB165920  10/01/2013 09:00:00 AM      077XX S NORMAL AVE
# 4      11247876    JB174736  10/23/2013 12:00:00 PM  065XX S MARSHFIELD AVE
# ...         ...         ...                     ...                     ...
# 73383   9989064    HY179269  12/02/2013 12:00:00 PM       006XX W WAYMAN ST
# 73384   9996021    HY186431  11/07/2013 09:00:00 AM         011XX W 13TH ST
# 73385   9997760    HY187799  10/01/2013 12:01:00 AM       015XX S DRAKE AVE
# 73386   9999937    HY189686  10/12/2013 09:00:00 AM        096XX S GREEN ST
# 73387   9999974    HY189951  12/01/2013 12:01:00 AM     121XX S INDIANA AVE
#
#        IUCR         Primary Type                              Description  \
# 0      0265  CRIM SEXUAL ASSAULT                        AGGRAVATED: OTHER
# 1      1153   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 2      1153   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3      1153   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 4      1153   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# ...     ...                  ...                                      ...
# 73383  0890                THEFT                            FROM BUILDING
# 73384  1153   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 73385  1154   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 73386  1153   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 73387  1153   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#       Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                RESIDENCE   False      True  ...  29.0              19
# 1                    OTHER   False     False  ...   9.0              50
# 2                RESIDENCE   False     False  ...  27.0              23
# 3                APARTMENT   False     False  ...  17.0              69
# 4                      NaN   False     False  ...  15.0              67
# ...                    ...     ...       ...  ...   ...             ...
# 73383            APARTMENT   False     False  ...  27.0              28
# 73384            RESIDENCE   False     False  ...   2.0              28
# 73385            RESIDENCE   False     False  ...  24.0              29
# 73386            RESIDENCE   False     False  ...  21.0              73
# 73387            RESIDENCE   False     False  ...   9.0              53
#
#        FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 0            02           NaN          NaN  2013  07/25/2017 03:48:23 PM
# 1            11           NaN          NaN  2013  08/02/2017 03:54:51 PM
# 2            11           NaN          NaN  2013  02/23/2018 03:57:04 PM
# 3            11           NaN          NaN  2013  02/27/2018 03:59:52 PM
# 4            11           NaN          NaN  2013  03/06/2018 04:00:51 PM
# ...         ...           ...          ...   ...                     ...
# 73383        06     1171576.0    1902339.0  2013  02/10/2018 03:50:01 PM
# 73384        11     1168818.0    1894211.0  2013  02/10/2018 03:50:01 PM
# 73385        11     1152957.0    1892178.0  2013  02/10/2018 03:50:01 PM
# 73386        11     1172344.0    1840881.0  2013  02/10/2018 03:50:01 PM
# 73387        11     1179759.0    1824639.0  2013  02/10/2018 03:50:01 PM
#
#         Latitude  Longitude                       Location
# 0            NaN        NaN                            NaN
# 1            NaN        NaN                            NaN
# 2            NaN        NaN                            NaN
# 3            NaN        NaN                            NaN
# 4            NaN        NaN                            NaN
# ...          ...        ...                            ...
# 73383  41.887481 -87.645373  (41.887481203, -87.645372811)
# 73384  41.865238 -87.655737  (41.865237588, -87.655736606)
# 73385  41.859988 -87.714017  (41.859987581, -87.714016828)
# 73386  41.718817 -87.644362  (41.718817166, -87.644361598)
# 73387  41.674081 -87.617697  (41.674080811, -87.617697384)
#
# [73388 rows x 22 columns]

# %%
# 7 columns with one or more null values
crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73388 entries, 0 to 73387
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    73388 non-null  int64
#  1   Case Number           73388 non-null  object
#  2   Date                  73388 non-null  object
#  3   Block                 73388 non-null  object
#  4   IUCR                  73388 non-null  object
#  5   Primary Type          73388 non-null  object
#  6   Description           73388 non-null  object
#  7   Location Description  73353 non-null  object
#  8   Arrest                73388 non-null  bool
#  9   Domestic              73388 non-null  bool
#  10  Beat                  73388 non-null  int64
#  11  District              73388 non-null  int64
#  12  Ward                  73387 non-null  float64
#  13  Community Area        73388 non-null  int64
#  14  FBI Code              73388 non-null  object
#  15  X Coordinate          73160 non-null  float64
#  16  Y Coordinate          73160 non-null  float64
#  17  Year                  73388 non-null  int64
#  18  Updated On            73388 non-null  object
#  19  Latitude              73160 non-null  float64
#  20  Longitude             73160 non-null  float64
#  21  Location              73160 non-null  object
# dtypes: bool(2), float64(5), int64(5), object(10)
# memory usage: 11.3+ MB

# %%
# Drop the na values reduces rows from 73388 rows to 73160
crime_data_dropna = crime_data.dropna()

# %%
crime_data_dropna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73151 entries, 192 to 73387
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    73151 non-null  int64
#  1   Case Number           73151 non-null  object
#  2   Date                  73151 non-null  object
#  3   Block                 73151 non-null  object
#  4   IUCR                  73151 non-null  object
#  5   Primary Type          73151 non-null  object
#  6   Description           73151 non-null  object
#  7   Location Description  73151 non-null  object
#  8   Arrest                73151 non-null  bool
#  9   Domestic              73151 non-null  bool
#  10  Beat                  73151 non-null  int64
#  11  District              73151 non-null  int64
#  12  Ward                  73151 non-null  float64
#  13  Community Area        73151 non-null  int64
#  14  FBI Code              73151 non-null  object
#  15  X Coordinate          73151 non-null  float64
#  16  Y Coordinate          73151 non-null  float64
#  17  Year                  73151 non-null  int64
#  18  Updated On            73151 non-null  object
#  19  Latitude              73151 non-null  float64
#  20  Longitude             73151 non-null  float64
#  21  Location              73151 non-null  object
# dtypes: bool(2), float64(5), int64(5), object(10)
# memory usage: 11.9+ MB

# %%
crime_data_dropna.describe()
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  7.315100e+04  73151.000000  73151.000000  73151.000000    73151.000000
# mean   9.380242e+06   1155.240010     11.324192     22.994286       37.309100
# std    3.543314e+05    695.075514      6.941863     13.883583       21.439319
# min    2.110000e+04    111.000000      1.000000      1.000000        1.000000
# 25%    9.358752e+06    613.000000      6.000000     10.000000       23.000000
# 50%    9.389890e+06   1032.000000     10.000000     23.000000       32.000000
# 75%    9.419581e+06   1712.000000     17.000000     34.000000       56.000000
# max    1.189733e+07   2535.000000     25.000000     50.000000       77.000000
#
#        X Coordinate  Y Coordinate     Year      Latitude     Longitude
# count  7.315100e+04  7.315100e+04  73151.0  73151.000000  73151.000000
# mean   1.164360e+06  1.885780e+06   2013.0     41.842180    -87.672379
# std    1.711756e+04  3.217544e+04      0.0      0.088524      0.062104
# min    0.000000e+00  0.000000e+00   2013.0     36.619446    -91.686566
# 25%    1.152455e+06  1.858674e+06   2013.0     41.767570    -87.715698
# 50%    1.166001e+06  1.892596e+06   2013.0     41.861023    -87.666123
# 75%    1.176352e+06  1.909036e+06   2013.0     41.906221    -87.628099
# max    1.205116e+06  1.951493e+06   2013.0     42.022535    -87.524529

# %% [markdown]
# ### <font color="red">NOTE: if reloading then must run the commented out line below, once, then comment out

# %%
#crime_data_dropna.set_index("ID")  # must run this once with new data
crime_data_dropna
# Out:
#         Case Number                    Date                      Block  IUCR  \
# ID
# 9420598    HW564211  12/09/2013 09:00:00 AM          066XX S PERRY AVE  141A
# 9383987    HW527086  11/08/2013 10:30:00 PM         029XX S ARCHER AVE  1753
# 9329556    HW473455  09/30/2013 06:00:00 AM         087XX S BURLEY AVE  0486
# 9349826    HW493400  10/15/2013 08:00:00 AM  077XX S COTTAGE GROVE AVE  0486
# 9443164    HW587492  12/29/2013 02:40:00 AM            016XX W 83RD ST  1310
# ...             ...                     ...                        ...   ...
# 9989064    HY179269  12/02/2013 12:00:00 PM          006XX W WAYMAN ST  0890
# 9996021    HY186431  11/07/2013 09:00:00 AM            011XX W 13TH ST  1153
# 9997760    HY187799  10/01/2013 12:01:00 AM          015XX S DRAKE AVE  1154
# 9999937    HY189686  10/12/2013 09:00:00 AM           096XX S GREEN ST  1153
# 9999974    HY189951  12/01/2013 12:01:00 AM        121XX S INDIANA AVE  1153
#
#                        Primary Type                              Description  \
# ID
# 9420598           WEAPONS VIOLATION                     UNLAWFUL USE HANDGUN
# 9383987  OFFENSE INVOLVING CHILDREN            SEX ASSLT OF CHILD BY FAM MBR
# 9329556                     BATTERY                  DOMESTIC BATTERY SIMPLE
# 9349826                     BATTERY                  DOMESTIC BATTERY SIMPLE
# 9443164             CRIMINAL DAMAGE                              TO PROPERTY
# ...                             ...                                      ...
# 9989064                       THEFT                            FROM BUILDING
# 9996021          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 9997760          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 9999937          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 9999974          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#         Location Description  Arrest  Domestic  Beat  ...  Ward  \
# ID                                                    ...
# 9420598            RESIDENCE    True     False   722  ...   6.0
# 9383987            APARTMENT    True     False   913  ...  11.0
# 9329556            APARTMENT   False      True   424  ...  10.0
# 9349826            APARTMENT   False      True   624  ...   8.0
# 9443164            APARTMENT   False      True   614  ...  21.0
# ...                      ...     ...       ...   ...  ...   ...
# 9989064            APARTMENT   False     False  1214  ...  27.0
# 9996021            RESIDENCE   False     False  1232  ...   2.0
# 9997760            RESIDENCE   False     False  1021  ...  24.0
# 9999937            RESIDENCE   False     False  2223  ...  21.0
# 9999974            RESIDENCE   False     False   532  ...   9.0
#
#          Community Area  FBI Code X Coordinate  Y Coordinate  Year  \
# ID
# 9420598              69        15    1176539.0     1860981.0  2013
# 9383987              60        02    1168200.0     1885556.0  2013
# 9329556              46       08B    1199185.0     1847694.0  2013
# 9349826              69       08B    1182903.0     1853956.0  2013
# 9443164              71        14    1166660.0     1849667.0  2013
# ...                 ...       ...          ...           ...   ...
# 9989064              28        06    1171576.0     1902339.0  2013
# 9996021              28        11    1168818.0     1894211.0  2013
# 9997760              29        11    1152957.0     1892178.0  2013
# 9999937              73        11    1172344.0     1840881.0  2013
# 9999974              53        11    1179759.0     1824639.0  2013
#
#                      Updated On   Latitude  Longitude  \
# ID
# 9420598  06/17/2019 04:07:59 PM  41.773881 -87.628394
# 9383987  06/27/2019 04:00:43 PM  41.841501 -87.658255
# 9329556  07/20/2019 04:04:54 PM  41.736881 -87.545825
# 9349826  07/20/2019 04:04:54 PM  41.754458 -87.605283
# 9443164  07/20/2019 04:04:54 PM  41.743050 -87.664930
# ...                         ...        ...        ...
# 9989064  02/10/2018 03:50:01 PM  41.887481 -87.645373
# 9996021  02/10/2018 03:50:01 PM  41.865238 -87.655737
# 9997760  02/10/2018 03:50:01 PM  41.859988 -87.714017
# 9999937  02/10/2018 03:50:01 PM  41.718817 -87.644362
# 9999974  02/10/2018 03:50:01 PM  41.674081 -87.617697
#
#                               Location
# ID
# 9420598  (41.773880868, -87.628393665)
# 9383987  (41.841500872, -87.658255083)
# 9329556  (41.736881094, -87.545825475)
# 9349826  (41.754458054, -87.605282723)
# 9443164  (41.743050207, -87.664930307)
# ...                                ...
# 9989064  (41.887481203, -87.645372811)
# 9996021  (41.865237588, -87.655736606)
# 9997760  (41.859987581, -87.714016828)
# 9999937  (41.718817166, -87.644361598)
# 9999974  (41.674080811, -87.617697384)
#
# [73151 rows x 21 columns]

# %%
crime_data_dropna['Primary Type'].value_counts()
# Out:
# THEFT                               17952
# BATTERY                             12356
# NARCOTICS                            7923
# CRIMINAL DAMAGE                      7333
# BURGLARY                             4655
# OTHER OFFENSE                        4129
# ASSAULT                              4045
# DECEPTIVE PRACTICE                   3386
# ROBBERY                              3117
# MOTOR VEHICLE THEFT                  2919
# CRIMINAL TRESPASS                    1868
# WEAPONS VIOLATION                     671
# PUBLIC PEACE VIOLATION                668
# OFFENSE INVOLVING CHILDREN            576
# PROSTITUTION                          312
# CRIM SEXUAL ASSAULT                   294
# INTERFERENCE WITH PUBLIC OFFICER      267
# SEX OFFENSE                           210
# HOMICIDE                              103
# LIQUOR LAW VIOLATION                   87
# GAMBLING                               72
# ARSON                                  69
# KIDNAPPING                             49
# STALKING                               39
# INTIMIDATION                           35
# CRIMINAL SEXUAL ASSAULT                 4
# OBSCENITY                               4
# PUBLIC INDECENCY                        3
# NON - CRIMINAL                          2
# NON-CRIMINAL                            2
# OTHER NARCOTIC VIOLATION                1
# Name: Primary Type, dtype: int64

# %%
crime_data_dropna['Description'].value_counts()
# Out:
# $500 AND UNDER                                 6996
# SIMPLE                                         6943
# DOMESTIC BATTERY SIMPLE                        6291
# OVER $500                                      4259
# POSS: CANNABIS 30GMS OR LESS                   3571
#                                                ...
# SOLICIT OFF PUBLIC WAY                            1
# VIOLATION GPS MONITORING DEVICE                   1
# UNLAWFUL USE OF A COMPUTER                        1
# UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL       1
# INSURANCE FRAUD                                   1
# Name: Description, Length: 273, dtype: int64

# %%
crime_data_dropna['Description'].describe()
# Out:
# count              73151
# unique               273
# top       $500 AND UNDER
# freq                6996
# Name: Description, dtype: object

# %%
crime_data_dropna['Description'].unique()
# Out:
# array(['UNLAWFUL USE HANDGUN', 'SEX ASSLT OF CHILD BY FAM MBR',
#        'DOMESTIC BATTERY SIMPLE', 'TO PROPERTY', 'FIRST DEGREE MURDER',
#        'AGG CRIMINAL SEXUAL ABUSE', 'CHILD ABUSE', 'FORCIBLE ENTRY',
#        'AGGRAVATED - HANDGUN', 'SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER',
#        'AGGRAVATED - OTHER', 'NON-AGGRAVATED',
#        'AGGRAVATED VEHICULAR HIJACKING',
#        'AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER',
#        'ARSON THREAT', 'OVER $500', 'ARMED: HANDGUN', 'SIMPLE',
#        '$500 AND UNDER', 'UNLAWFUL ENTRY', 'STRONGARM - NO WEAPON',
#        'FROM BUILDING', 'RETAIL THEFT', 'TO VEHICLE',
#        'POSS: CANNABIS 30GMS OR LESS', 'POSS: CRACK', 'AGGRAVATED',
#        'FRAUD OR CONFIDENCE GAME', 'FINANCIAL IDENTITY THEFT OVER $ 300',
#        'AGGRAVATED FINANCIAL IDENTITY THEFT', 'EMBEZZLEMENT',
#        'MANU/DELIVER:CRACK', 'FINANCIAL IDENTITY THEFT $300 AND UNDER',
#        'ILLEGAL USE CASH CARD', 'CREDIT CARD FRAUD', 'FORGERY',
#        'AUTOMOBILE', 'CRIM SEX ABUSE BY FAM MEMBER',
#        'CRIMINAL SEXUAL ABUSE', 'OTHER CRIME AGAINST PERSON',
#        'AGGRAVATED: OTHER', 'ATTEMPT NON-AGGRAVATED',
#        'FINAN EXPLOIT-ELDERLY/DISABLED', 'UNAUTHORIZED VIDEOTAPING',
#        'POSS: HEROIN(WHITE)', 'PREDATORY',
#        'HARASSMENT BY ELECTRONIC MEANS',
#        'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON', 'BOGUS CHECK',
#        'VIOLATE ORDER OF PROTECTION', 'MANU/DEL:CANNABIS OVER 10 GMS',
#        'AGGRAVATED: HANDGUN', 'RECKLESS CONDUCT',
#        'AGG PO HANDS NO/MIN INJURY', 'TO LAND',
#        'AGGRAVATED: OTHER DANG WEAPON', 'TO CITY OF CHICAGO PROPERTY',
#        'LIQUOR LICENSE VIOLATION', 'BY FIRE', 'UNLAWFUL POSS OF HANDGUN',
#        'AGGRAVATED:KNIFE/CUTTING INSTR', 'CRIMINAL DEFACEMENT',
#        'PURSE-SNATCHING', 'POCKET-PICKING', 'OTHER VEHICLE OFFENSE',
#        'THEFT OF LABOR/SERVICES', 'SOLICIT ON PUBLIC WAY',
#        'SOLICIT NARCOTICS ON PUBLICWAY', 'ARMED: OTHER DANGEROUS WEAPON',
#        'POSS FIREARM/AMMO:NO FOID CARD', 'COUNTERFEITING DOCUMENT',
#        'THEFT/RECOVERY: AUTOMOBILE', 'POSSESSION OF DRUG EQUIPMENT',
#        'OTHER OFFENSE', 'HARASSMENT BY TELEPHONE',
#        'MANU/DEL:CANNABIS 10GM OR LESS', 'TAMPER WITH MOTOR VEHICLE',
#        'MANU/DELIVER: HEROIN (WHITE)',
#        'AGG: HANDS/FIST/FEET SERIOUS INJURY', 'TO STATE SUP LAND',
#        'TELEPHONE THREAT', 'POSS: PCP', 'FINANCIAL ID THEFT: OVER $300',
#        'ATTEMPT FORCIBLE ENTRY', 'POSS: HALLUCINOGENS',
#        'ATTEMPT: ARMED-HANDGUN', 'AGGRAVATED PO: OTHER DANG WEAP',
#        'ATTEMPT: STRONGARM-NO WEAPON', 'RESIST/OBSTRUCT/DISARM OFFICER',
#        'AGGRAVATED OF A SENIOR CITIZEN', 'STOLEN PROP: BUY/RECEIVE/POS.',
#        'TO RESIDENCE', 'VEHICULAR HIJACKING', 'ATTEMPT THEFT',
#        'ARMED:KNIFE/CUTTING INSTRUMENT', 'CYCLE, SCOOTER, BIKE W-VIN',
#        'GAME/DICE', 'FOUND SUSPECT NARCOTICS', 'LICENSE VIOLATION',
#        'POSS: COCAINE', 'FORFEIT PROPERTY', 'OBSTRUCTING IDENTIFICATION',
#        'ENDANGERING LIFE/HEALTH CHILD', 'MANU/DELIVER:COCAINE',
#        'UNLAWFUL USE OTHER DANG WEAPON', 'ILLEGAL CONSUMPTION BY MINOR',
#        'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST', 'HOME INVASION',
#        'AGG: HANDS/FIST/FEET NO/MINOR INJURY', 'ANIMAL ABUSE/NEGLECT',
#        'THEFT/RECOVERY: TRUCK,BUS,MHOME',
#        'GUN OFFENDER: ANNUAL REGISTRATION', 'PUBLIC INDECENCY',
#        'INTIMIDATION', 'ARMED: OTHER FIREARM',
#        'THEFT OF LOST/MISLAID PROP', 'UNLAWFUL USE OF RECORDED SOUND',
#        'CALL OPERATION', 'PRO EMP HANDS NO/MIN INJURY',
#        'PROBATION VIOLATION', 'FALSE/STOLEN/ALTERED TRP',
#        'OTHER CRIME INVOLVING PROPERTY', 'POSS: SYNTHETIC DRUGS',
#        'TRUCK, BUS, MOTOR HOME',
#        'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY',
#        'ATT: AUTOMOBILE', 'FALSE FIRE ALARM', 'CHILD ABDUCTION',
#        'PAROLE VIOLATION', 'FALSE POLICE REPORT',
#        'VEHICLE TITLE/REG OFFENSE', 'SOLICIT OFF PUBLIC WAY',
#        'OBSTRUCTING JUSTICE', 'ATTEMPT FINANCIAL IDENTITY THEFT',
#        'GUN OFFENDER: DUTY TO REGISTER', 'POSS: CANNABIS MORE THAN 30GMS',
#        'AGGRAVATED PO: HANDGUN', 'UNLAWFUL USE OTHER FIREARM',
#        'SEX RELATION IN FAMILY', 'UNLAWFUL POSS AMMUNITION',
#        'ILLEGAL POSSESSION BY MINOR', 'EXTORTION', 'CHILD ABANDONMENT',
#        'ATTEMPT AGG: OTHER', 'UNLAWFUL USE/SALE AIR RIFLE',
#        'SEX OFFENDER: FAIL TO REGISTER', 'UNLAWFUL POSS OTHER FIREARM',
#        'SOLICIT FOR PROSTITUTE', 'COUNTERFEIT CHECK',
#        'AGG: FINANCIAL ID THEFT', 'POSS: HEROIN(BRN/TAN)', 'BOMB THREAT',
#        'AGGRAVATED PO:KNIFE/CUT INSTR', 'SELL/GIVE/DEL LIQUOR TO MINOR',
#        'OTHER WEAPONS VIOLATION', 'ESCAPE', 'CHILD ABDUCTION/STRANGER',
#        'POSSESSION OF BURGLARY TOOLS', 'ATTEMPT: ARMED-OTHER DANG WEAP',
#        'MOB ACTION', 'UNLAWFUL INTERFERE/VISITATION',
#        'SEX OFFENDER: PROHIBITED ZONE', 'OTHER VIOLATION',
#        'UNIDENTIFIABLE RECORDING SOUND', 'TO STATE SUP PROP',
#        'ATTEMPT: AGGRAVATED', 'UNLAWFUL RESTRAINT', 'PEEPING TOM',
#        'OBSTRUCTING SERVICE', 'POSS: METHAMPHETAMINES',
#        'TO FIRE FIGHT.APP.EQUIP',
#        'VIOLATION OF STALKING NO CONTACT ORDER',
#        'ATTEMPT: ARMED-KNIFE/CUT INSTR', 'POS: EXPLOSIVE/INCENDIARY DEV',
#        'POSS: BARBITUATES', 'FINANCIAL ID THEFT:$300 &UNDER',
#        'CHILD PORNOGRAPHY', 'FROM COIN-OP MACHINE/DEVICE',
#        'MANU/DELIVER:PCP', 'OTHER', 'POSS: AMPHETAMINES',
#        'OBSCENE TELEPHONE CALLS', 'DEL CONT SUBS TO PERSON <18',
#        'AGG PRO.EMP: OTHER DANG WEAPON', 'POS: HYPODERMIC NEEDLE',
#        'PATRONIZING A PROSTITUTE', 'MANU/DELIVER: HEROIN(BRN/TAN)',
#        'AGGRAVATED: KNIFE/CUT INSTR', 'MANU/DELIVER:BARBITUATES',
#        'SEX OFFENDER: FAIL REG NEW ADD', 'INDECENT SOLICITATION/CHILD',
#        'ILLEGAL POSSESSION CASH CARD', 'AGGRAVATED: OTHER FIREARM',
#        'THEFT BY LESSEE,MOTOR VEH', 'MANU/DELIVER:AMPHETAMINES',
#        'DELIVERY CONTAINER THEFT', 'AGGRAVATED OF A CHILD',
#        'AGGRAVATED OF A UNBORN CHILD', 'RECKLESS FIREARM DISCHARGE',
#        'ATT CRIM SEXUAL ABUSE', 'OBSCENE MATTER',
#        'SEXUAL EXPLOITATION OF A CHILD', 'CYBERSTALKING',
#        'ATTEMPT: ARMED-OTHER FIREARM', 'SOLICIT FOR BUSINESS',
#        'AGG CRIM SEX ABUSE FAM MEMBER', 'COMPUTER FRAUD',
#        'CANNABIS PLANT', 'ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN',
#        'POSSESSION: SYNTHETIC MARIJUANA', 'ATTEMPT AGG: KNIFE/CUT INSTR',
#        'MANU/DELIVER:SYNTHETIC DRUGS', 'BOARD PLANE WITH WEAPON',
#        'MONEY LAUNDERING', 'CRIMINAL DRUG CONSPIRACY', 'OF UNBORN CHILD',
#        'THEFT BY LESSEE,NON-VEH', 'IMPERSONATION', 'HARBOR RUNAWAY',
#        'INTERFERENCE JUDICIAL PROCESS', 'AGG PRO.EMP: HANDGUN',
#        'INSURANCE FRAUD', 'LIBRARY THEFT', 'POSS: HEROIN(BLACK TAR)',
#        'AGGRAVATED PO: KNIFE/CUT INSTR', 'ATTEMPT ARSON',
#        'FIREARM REGISTRATION VIOLATION', 'DECEPTIVE COLLECTION PRACTICES',
#        'FOID - REVOCATION', 'CONTRIBUTE DELINQUENCY OF A CHILD',
#        'ALTER/FORGE PRESCRIPTION', 'AGG PRO.EMP:KNIFE/CUTTING INST',
#        'ATT: TRUCK, BUS, MOTOR HOME', 'VIO BAIL BOND: DOM VIOLENCE',
#        'PAY TV SERVICE OFFENSES', 'KIDNAPPING',
#        'AGG SEX ASSLT OF CHILD FAM MBR', 'LICENSED PREMISE',
#        'OTHER ARSON/EXPLOSIVE INCIDENT', 'TO AIRPORT',
#        'MANU/DELIVER: HALLUCINOGEN', 'AGG PO HANDS ETC SERIOUS INJ',
#        'CONTRIBUTE CRIM DELINQUENCY JUVENILE', 'INSTITUTIONAL VANDALISM',
#        'MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA',
#        'VIOLATION GPS MONITORING DEVICE',
#        'SALE TOBACCO PRODUCTS TO MINOR', 'MANU/DELIVER: METHAMPHETAMINES',
#        'MANU/DELIVER:HEROIN(BLACK TAR)', 'AGG PRO EMP HANDS SERIOUS INJ',
#        'LOST PASSPORT', 'POSS: LOOK-ALIKE DRUGS',
#        'SALE/DEL DRUG PARAPHERNALIA', 'ATTEMPT POSSESSION NARCOTICS',
#        'INVOLUNTARY MANSLAUGHTER', 'CYCLE, SCOOTER, BIKE NO VIN',
#        'INTOXICATING COMPOUNDS',
#        'UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL',
#        'CALCULATED CANNABIS CONSPIRACY', 'INDECENT SOLICITATION/ADULT',
#        'INTERFERE W/ HIGHER EDUCATION', 'MANU/DELIVER:LOOK-ALIKE DRUG',
#        'KEEP PLACE OF PROSTITUTION', 'COMPELLING ORG MEMBERSHIP',
#        'EAVESDROPPING', 'VIOLATION OF SMOKING BAN',
#        'UNLAWFUL USE OF A COMPUTER', 'CONT SUBS:FAIL TO MAINT RECORD',
#        'OTHER PROSTITUTION OFFENSE', 'OBSCENITY', 'BRIBERY',
#        'ATTEMPT - FINANCIAL IDENTITY THEFT', 'UNLAWFUL SALE HANDGUN'],
#       dtype=object)

# %%
crime_data_dropna['Block'].value_counts()
# Out:
# 001XX N STATE ST        269
# 0000X W TERMINAL ST     150
# 008XX N MICHIGAN AVE    143
# 046XX W NORTH AVE       117
# 076XX S CICERO AVE      117
#                        ...
# 037XX N BERNARD ST        1
# 003XX E 38TH ST           1
# 016XX W ROSEHILL DR       1
# 050XX S PEORIA ST         1
# 063XX S MAJOR AVE         1
# Name: Block, Length: 19798, dtype: int64

# %% [markdown]
# ### Pandas Profiling Summaries

# %%
crime_data_profile = ProfileReport(crime_data_dropna, title='Pandas Profiling Report')

# %%
crime_data_profile.to_widgets()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=36.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render widgets', max=1.0, style=ProgressStyle(description…
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
crime_data_profile.to_file('../data/processed/crime_data_profile.html') # '../data/raw/chicago30dayData22sep2020.csv'
